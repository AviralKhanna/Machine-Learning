# %%
import pandas as pd
import numpy as np

import os
import sys

# librosa is a Python library for analyzing audio and music. It can be used to extract the data from the audio files we will see it later.
import librosa
import librosa.display
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

# to play the audio files
from IPython.display import Audio

import keras
from keras.callbacks import ReduceLROnPlateau
from keras.models import Sequential
from keras.layers import Dense, Conv1D, MaxPooling1D, Flatten, Dropout, BatchNormalization
from keras.utils import np_utils, to_categorical
from keras.callbacks import ModelCheckpoint

# %%
#plt.figure(figsize=(14, 5))
#data, sample_rate = librosa.load(filename)
#librosa.display.waveplot(data, sr=sample_rate)
#ipd.Audio(filename)  # This will play the audio
#plt.show()

# %%
# Load the audio file
data, sample_rate = librosa.load(filename)

# Create a time array matching the duration of the audio
time = librosa.times_like(data, sr=sample_rate)

# Plot the waveform
plt.figure(figsize=(14, 5))
plt.plot(time, data)
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.title('Audio Waveform')
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-4058d2aadab4> in <cell line: 2>()
#       1 # Load the audio file
# ----> 2 data, sample_rate = librosa.load(filename)
#       3
#       4 # Create a time array matching the duration of the audio
#       5 time = librosa.times_like(data, sr=sample_rate)
#
# NameError: name 'filename' is not defined

# %%
sample_rate
# Out:
# 22050

# %%
from scipy.io import wavfile as wav
wave_sample_rate, wave_audio=wav.read(filename)

# %%
wave_sample_rate
# Out:
# 44100

# %%
wave_audio
# Out:
# array([1573, 1573, 1573, ..., 1338, 1315, 1296], dtype=int16)

# %%
data
# Out:
# array([0.03548561, 0.05175975, 0.0457577 , ..., 0.04195745, 0.04038323,
#        0.04235241], dtype=float32)

# %%
#metadata=pd.read_csv('/content/drive/MyDrive/ALL/metadata/ALL.csv')
#metadata.head(10)

# %%
import pandas as pd
import numpy as np

import os
import sys

# librosa is a Python library for analyzing audio and music. It can be used to extract the data from the audio files we will see it later.
import librosa
import librosa.display
import seaborn as sns
import matplotlib.pyplot as plt

# %%
Savee = "/content/drive/MyDrive/ALL"
savee_directory_list = os.listdir(Savee)

# %%
file_emotion = []
file_path = []

# %%
for file in savee_directory_list:
    file_path.append(Savee + file)
    part = file.split('_')[1]
    ele = part[:-6]
    if ele=='a':
        file_emotion.append('angry')
    elif ele=='d':
        file_emotion.append('disgust')
    elif ele=='f':
        file_emotion.append('fear')
    elif ele=='h':
        file_emotion.append('happy')
    elif ele=='n':
        file_emotion.append('neutral')
    elif ele=='sa':
        file_emotion.append('sad')
    else:
        file_emotion.append('surprise')

# %%
# dataframe for emotion of files
emotion_df = pd.DataFrame(file_emotion, columns=['Emotions'])

# dataframe for path of files.
path_df = pd.DataFrame(file_path, columns=['Path'])
Savee_df = pd.concat([emotion_df, path_df], axis=1)
Savee_df.head()
# Out:
#   Emotions                                  Path
# 0    angry  /content/drive/MyDrive/ALLDC_a12.wav
# 1    angry  /content/drive/MyDrive/ALLDC_a02.wav
# 2    angry  /content/drive/MyDrive/ALLDC_a07.wav
# 3    angry  /content/drive/MyDrive/ALLDC_a08.wav
# 4    angry  /content/drive/MyDrive/ALLDC_a11.wav

# %%
# dataframe for emotion of files
emotion_df = pd.DataFrame(file_emotion, columns=['Emotions'])

# %%
# dataframe for path of files.
path_df = pd.DataFrame(file_path, columns=['Path'])
Savee_df = pd.concat([emotion_df, path_df], axis=1)
Savee_df.head(50)
# Out:
#    Emotions                                  Path
# 0     angry  /content/drive/MyDrive/ALLDC_a12.wav
# 1     angry  /content/drive/MyDrive/ALLDC_a02.wav
# 2     angry  /content/drive/MyDrive/ALLDC_a07.wav
# 3     angry  /content/drive/MyDrive/ALLDC_a08.wav
# 4     angry  /content/drive/MyDrive/ALLDC_a11.wav
# 5     angry  /content/drive/MyDrive/ALLDC_a09.wav
# 6     angry  /content/drive/MyDrive/ALLDC_a03.wav
# 7     angry  /content/drive/MyDrive/ALLDC_a06.wav
# 8     angry  /content/drive/MyDrive/ALLDC_a05.wav
# 9     angry  /content/drive/MyDrive/ALLDC_a10.wav
# 10    angry  /content/drive/MyDrive/ALLDC_a04.wav
# 11    angry  /content/drive/MyDrive/ALLDC_a01.wav
# 12  disgust  /content/drive/MyDrive/ALLDC_d14.wav
# 13  neutral  /content/drive/MyDrive/ALLDC_n11.wav
# 14  disgust  /content/drive/MyDrive/ALLDC_d01.wav
# 15     fear  /content/drive/MyDrive/ALLDC_f06.wav
# 16  disgust  /content/drive/MyDrive/ALLDC_d11.wav
# 17  neutral  /content/drive/MyDrive/ALLDC_n02.wav
# ...

# %%
emotion_df = pd.DataFrame(file_emotion, columns=['Emotions'])
path_df = pd.DataFrame(file_path, columns=['Path'])

# %%
# Concatenate dataframes to create the final dataframe
Savee_df = pd.concat([emotion_df, path_df], axis=1)

# %%
# Display the first few rows of the dataframe
print(Savee_df.head())
# Out:
#   Emotions                                  Path
# 0    angry  /content/drive/MyDrive/ALLDC_a12.wav
# 1    angry  /content/drive/MyDrive/ALLDC_a02.wav
# 2    angry  /content/drive/MyDrive/ALLDC_a07.wav
# 3    angry  /content/drive/MyDrive/ALLDC_a08.wav
# 4    angry  /content/drive/MyDrive/ALLDC_a11.wav

# %%
# Save the DataFrame as a CSV file
csv_filename = "selected_audio_data.csv"
Savee_df.to_csv(csv_filename, index=False)

# %%
print(f"CSV file '{csv_filename}' generated successfully.")
# Out:
# CSV file 'selected_audio_data.csv' generated successfully.

# %%
# creating Dataframe using all the 4 dataframes we created so far.
data_path = pd.concat([Savee_df], axis = 0)
data_path.to_csv("/content/selected_audio_data.csv",index=False)
data_path.head()
# Out:
#   Emotions                                  Path
# 0    angry  /content/drive/MyDrive/ALLDC_a12.wav
# 1    angry  /content/drive/MyDrive/ALLDC_a02.wav
# 2    angry  /content/drive/MyDrive/ALLDC_a07.wav
# 3    angry  /content/drive/MyDrive/ALLDC_a08.wav
# 4    angry  /content/drive/MyDrive/ALLDC_a11.wav

# %%
import csv

# opening the CSV file
with open('/content/selected_audio_data.csv', mode ='r')as file:

  # reading the CSV file
  csvFile = csv.reader(file)

  # displaying the contents of the CSV file
  for lines in csvFile:
        print(lines)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-e76c63556617> in <cell line: 4>()
#       2
#       3 # opening the CSV file
# ----> 4 with open('/content/selected_audio_data.csv', mode ='r')as file:
#       5
#       6   # reading the CSV file
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/selected_audio_data.csv'

# %%
 Plot the count of emotions
plt.figure(figsize=(10, 6))
plt.title('Count of Emotions', size=16)
sns.countplot(data=data_path, x='Emotions')  # Specify 'x' to indicate the column containing categorical data
plt.ylabel('Count', size=12)
plt.xlabel('Emotions', size=12)
sns.despine(top=True, right=True, left=False, bottom=False)
plt.show()

# %%
def create_waveplot(data, sr, e):
    plt.figure(figsize=(10, 3))
    plt.title('Waveplot for audio with {} emotion'.format(e), size=15)
    librosa.display.waveplot(data, sr=sr)
    plt.show()

# %%
def create_spectrogram(data, sr, e):
    # stft function converts the data into short term fourier transform
    X = librosa.stft(data)
    Xdb = librosa.amplitude_to_db(abs(X))
    plt.figure(figsize=(12, 3))
    plt.title('Spectrogram for audio with {} emotion'.format(e), size=15)
    librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz')
    #librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='log')
    plt.colorbar()

# %%
emotion = 'fear'
paths_ = "/content/drive/MyDrive/ALL/DC_f10.wav"
data, sampling_rate = librosa.load(paths_)
plt.figure(figsize=(14, 5))
librosa.display.waveshow(data, sr=sampling_rate)
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.title(f'Waveform of {emotion} Emotion')
plt.show()

# %%
from IPython.display import Audio  # Import the Audio class

# %%
# Use the Audio class to play the audio
audio_widget = Audio(data, rate=sampling_rate)
display(audio_widget)

# %%
emotion = 'angry'
path = "/content/drive/MyDrive/ALL/DC_a10.wav"
data, sampling_rate = librosa.load(path)
plt.figure(figsize=(14, 5))
librosa.display.waveshow(data, sr=sampling_rate)
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.title(f'Waveform of {emotion} Emotion')
plt.show()

# %%
# Use the Audio class to play the audio
audio_widget = Audio(data, rate=sampling_rate)
display(audio_widget)

# %%
emotion='sad'
path = np.array(data_path.Path[data_path.Emotions==emotion])[1]
xy=path

# %%
print(xy)
# Out:
# /content/drive/MyDrive/ALLDC_sa02.wav

# %%
path='/content/drive/MyDrive/ALLDC_sa02.wav'

# %%
data, sampling_rate = librosa.load(path)
plt.figure(figsize=(14, 5))
librosa.display.waveshow(data, sr=sampling_rate)
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.title(f'Waveform of {emotion} Emotion')
plt.show()
audio_widget = Audio(data, rate=sampling_rate)
display(audio_widget)
# Out:
# <ipython-input-43-339d2a448e56>:1: UserWarning: PySoundFile failed. Trying audioread instead.
#   data, sampling_rate = librosa.load(path)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# ---------------------------------------------------------------------------
# LibsndfileError                           Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py in load(path, sr, mono, offset, duration, dtype, res_type)
#     175         try:
# --> 176             y, sr_native = __soundfile_load(path, offset, duration, dtype)
#     177
#
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py in __soundfile_load(path, offset, duration, dtype)
#     208         # Otherwise, create the soundfile object
# ...

# %%
xy=""
emotion = 'sad'

xy = np.array(data_path.Path[data_path.Emotions==emotion])[1]
print(xy)
path=xy
data, sampling_rate = librosa.load(path)
plt.figure(figsize=(14, 5))
librosa.display.waveshow(data, sr=sampling_rate)
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.title(f'Waveform of {emotion} Emotion')
plt.show()
audio_widget = Audio(data, rate=sampling_rate)
display(audio_widget)
# Out:
# /content/drive/MyDrive/ALLDC_sa02.wav
# <ipython-input-31-f5bd24e63029>:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   data, sampling_rate = librosa.load(path)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# ---------------------------------------------------------------------------
# LibsndfileError                           Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py in load(path, sr, mono, offset, duration, dtype, res_type)
#     175         try:
# --> 176             y, sr_native = __soundfile_load(path, offset, duration, dtype)
#     177
#
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py in __soundfile_load(path, offset, duration, dtype)
# ...

# %%
def noise(data):
    noise_amp = 0.035*np.random.uniform()*np.amax(data)
    data = data + noise_amp*np.random.normal(size=data.shape[0])
    return data

# %%
def stretch(data, rate=0.8):
    return librosa.effects.time_stretch(data, rate)

# %%
def shift(data):
    shift_range = int(np.random.uniform(low=-5, high = 5)*1000)
    return np.roll(data, shift_range)

# %%
def pitch(data, sampling_rate, pitch_factor=0.7):
    return librosa.effects.pitch_shift(data, sampling_rate, pitch_factor)

# %%
#

# %%
data, sampling_rate = librosa.load("/content/drive/MyDrive/ALL/DC_sa10.wav")
plt.figure(figsize=(14, 5))
librosa.display.waveshow(data, sr=sampling_rate)
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.title(f'Waveform of {emotion} Emotion')
plt.show()
audio_widget = Audio(data, rate=sampling_rate)
display(audio_widget)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
x = noise(data)

# %%
# Plot the waveform using matplotlib
plt.figure(figsize=(14, 4))
plt.plot(x)
plt.xlabel('Sample')
plt.ylabel('Amplitude')
plt.title('Waveform with Noise Augmentation')
plt.grid()
plt.show()

# %%
# Play the audio with noise augmentation
audio_widget = Audio(x, rate=sample_rate)
display(audio_widget)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
x = librosa.effects.time_stretch(data, rate=0.8)  # Adjust the rate as needed

# %%
plt.figure(figsize=(14, 4))
plt.plot(x)
plt.xlabel('Sample')
plt.ylabel('Amplitude')
plt.title('Waveform with Time-Stretch Augmentation')
plt.grid()
plt.show()

# %%
# Play the audio with time-stretch augmentation
audio_widget = Audio(x, rate=sample_rate)
display(audio_widget)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Apply pitch shift augmentation to audio data
n_steps = 2  # Adjust n_steps as needed
x = librosa.effects.pitch_shift(data, sr=sample_rate, n_steps=n_steps)

# %%
# Plot the waveform using matplotlib
plt.figure(figsize=(14, 4))
plt.plot(x)
plt.xlabel('Sample')
plt.ylabel('Amplitude')
plt.title('Waveform with Pitch Shift Augmentation')
plt.grid()
plt.show()

# %%
data_path = pd.concat([Savee_df], axis = 0)
data_path.to_csv("data_path.csv",index=False)
data_path.head()
print(data_path)
# Out:
#      Emotions                                   Path
# 0       angry   /content/drive/MyDrive/ALLDC_a12.wav
# 1       angry   /content/drive/MyDrive/ALLDC_a02.wav
# 2       angry   /content/drive/MyDrive/ALLDC_a07.wav
# 3       angry   /content/drive/MyDrive/ALLDC_a08.wav
# 4       angry   /content/drive/MyDrive/ALLDC_a11.wav
# ..        ...                                    ...
# 475  surprise  /content/drive/MyDrive/ALLKL_su10.wav
# 476   neutral   /content/drive/MyDrive/ALLKL_n09.wav
# 477  surprise  /content/drive/MyDrive/ALLKL_su15.wav
# 478  surprise  /content/drive/MyDrive/ALLKL_su13.wav
# 479  surprise  /content/drive/MyDrive/ALLKL_su14.wav
#
# [480 rows x 2 columns]

# %%
paths = np.array(data_path.Path[data_path.Emotions==emotion])[1]

# %%
# Play the audio with pitch shift augmentation
audio_widget = Audio(x, rate=sample_rate)
display(audio_widget)
# Define the directory path containing your audio files
savee_directory = "/content/drive/MyDrive/ALL"  # Change this to your directory path
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Load the required libraries for feature extraction and machine learning
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC
import joblib

# %%
# Feature extraction function
def extract_features(data, sr):
    features = []

    # Zero Crossing Rate
    zcr = np.mean(librosa.feature.zero_crossing_rate(y=data).T, axis=0)
    features.append(zcr)

    # Chroma_stft
    stft = np.abs(librosa.stft(data))
    chroma_stft = np.mean(librosa.feature.chroma_stft(S=stft, sr=sr).T, axis=0)
    features.append(chroma_stft)

    # MFCC
    mfcc = np.mean(librosa.feature.mfcc(y=data, sr=sr).T, axis=0)
    features.append(mfcc)

    # Root Mean Square Value
    rms = np.mean(librosa.feature.rms(y=data).T, axis=0)
    features.append(rms)

    # MelSpectogram
    mel = np.mean(librosa.feature.melspectrogram(y=data, sr=sr).T, axis=0)
    features.append(mel)

    return np.concatenate(features)

# %%
# Apply feature extraction to all audio files
X = []
y = []

# %%
for idx, row in data_path.iterrows():
    emotion = row['Emotions']
    path = row['Path']

    print("Current path:", path)
    #data, sr = librosa.load(path, duration=2.5, offset=0.6)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-88bb4ed4f6ae> in <cell line: 1>()
# ----> 1 for idx, row in data_path.iterrows():
#       2     emotion = row['Emotions']
#       3     path = row['Path']
#       4
#       5     print("Current path:", path)
#
# NameError: name 'data_path' is not defined
